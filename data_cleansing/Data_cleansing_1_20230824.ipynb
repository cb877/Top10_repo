# %%
import pandas as pd

# %%
df = pd.read_excel("top_10.xlsx", sheet_name = "Females", skiprows = 2, header=[0,1])
#Return itself (x), if it is unnamed return empty''. Look into Lambda functions.
df = df.rename(columns=lambda x: x if not 'Unnamed' in str(x) else '')
#df.columns = df.columns.to_flat_index()
#list comprehension: Square brackets is list, for column, join with "-"
df.columns = ["_".join(column) for column in df.columns]
df.head()

#df.columns
#df = pd.Series(df.index).fillna(method='ffill')

#df = pd.read_excel("header_with_merged_cells.xlsx", skiprows=3, header=[0,1])
#df = df.reset_index()
#df = df.rename(columns=lambda x: x if not 'Unnamed' in str(x) else '')
#df = df.rename(columns={'index':'ColA'})
#df.columns.names = (None, None)
#print(df)
# Out:
#        Age1_ Year_19152 Year_19152.1       Year_19152.2 Year_19152.3  \
# 0        NaN       Rank   ICD-2 code  Underlying cause4    Total (N)
# 1  1-4 years          1            6            Measles         5544
# 2        NaN          2           91  Broncho-pneumonia         4135
# 3        NaN          3            8     Whooping cough         2397
# 4        NaN          4       89&90B   Other bronchitis         1632
#
#       Year_19152.4 Year_19252 Year_19252.1       Year_19252.2 Year_19252.3  \
# 0  Percentage (%)5       Rank   ICD-3 code  Underlying cause4    Total (N)
# 1             20.9          1          100  Broncho-pneumonia         2693
# 2             15.6          2            7            Measles         1785
# 3                9          2            9     Whooping cough         1785
# 4              6.2          4           10         Diphtheria          664
#
#    ... Year_20053 Year_20053.1  \
# 0  ...       Rank  ICD-10 code
# 1  ...          1          A39
# ...
